# %% [markdown]
# # Chapter 5 MyElite fine-tuning with Qwen
#
# - 데이터셋: `/data/chapter5/loyalty_qa_train.jsonl`, `/data/chapter5/loyalty_qa_val.jsonl`
# - 모델: `Qwen/Qwen2.5-0.5B-Instruct`
# - 산출물: `/model-assets`

# %%
import importlib.util
import subprocess
import sys

if importlib.util.find_spec("torch") is None:
  raise RuntimeError("PyTorch is missing. Check the JupyterHub image tag in eks/values/jupyterhub/values-example.yaml.")

package_modules = {
  "transformers": "transformers",
  "datasets": "datasets",
  "peft": "peft",
  "accelerate": "accelerate",
  "sentencepiece": "sentencepiece",
  "protobuf": "google.protobuf",
}

missing_packages = [
  package
  for package, module in package_modules.items()
  if importlib.util.find_spec(module) is None
]

if missing_packages:
  subprocess.check_call([sys.executable, "-m", "pip", "install", *missing_packages])

print("missing packages installed:", missing_packages or "none")
# Out:
# Collecting transformers
#   Using cached transformers-5.9.0-py3-none-any.whl.metadata (33 kB)
# Collecting datasets
#   Using cached datasets-4.8.5-py3-none-any.whl.metadata (19 kB)
# Collecting peft
#   Using cached peft-0.19.1-py3-none-any.whl.metadata (15 kB)
# Collecting accelerate
#   Using cached accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Collecting sentencepiece
#   Using cached sentencepiece-0.2.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers)
#   Using cached huggingface_hub-1.16.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.13/site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.13/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.13/site-packages (from transformers) (6.0.3)
# Collecting regex>=2025.10.22 (from transformers)
#   Using cached regex-2026.5.9-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typer (from transformers)
#   Using cached typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.13/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: filelock>=3.10.0 in /opt/conda/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.12.0)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Using cached hf_xet-1.5.0-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/conda/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /opt/conda/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/conda/lib/python3.13/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /opt/conda/lib/python3.13/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.13/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.13/site-packages (from datasets) (2.32.5)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.7.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.20 (from datasets)
#   Using cached multiprocess-0.70.19-py313-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.13/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.3)
# Collecting dill<0.4.2,>=0.3.0 (from datasets)
#   Using cached dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.13/site-packages (from peft) (7.2.1)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/lib/python3.13/site-packages (from peft) (2.9.1+cu128)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /opt/conda/lib/python3.13/site-packages (from torch>=1.13.0->peft) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /opt/conda/lib/python3.13/site-packages (from typer->transformers) (8.3.1)
# Collecting shellingham>=1.3.0 (from typer->transformers)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=13.8.0 in /opt/conda/lib/python3.13/site-packages (from typer->transformers) (14.2.0)
# Collecting annotated-doc>=0.0.2 (from typer->transformers)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.13/site-packages (from rich>=13.8.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.13/site-packages (from rich>=13.8.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.13/site-packages (from jinja2->torch>=1.13.0->peft) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.13/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.13/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.13/site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Using cached transformers-5.9.0-py3-none-any.whl (10.8 MB)
# Using cached huggingface_hub-1.16.1-py3-none-any.whl (668 kB)
# Using cached hf_xet-1.5.0-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.5 MB)
# Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Using cached datasets-4.8.5-py3-none-any.whl (528 kB)
# Using cached multiprocess-0.70.19-py313-none-any.whl (156 kB)
# Using cached dill-0.4.1-py3-none-any.whl (120 kB)
# Using cached peft-0.19.1-py3-none-any.whl (680 kB)
# Using cached accelerate-1.13.0-py3-none-any.whl (383 kB)
# Using cached sentencepiece-0.2.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
# Using cached regex-2026.5.9-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (801 kB)
# Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Using cached typer-0.25.1-py3-none-any.whl (58 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached xxhash-3.7.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Installing collected packages: xxhash, shellingham, sentencepiece, safetensors, regex, hf-xet, dill, annotated-doc, multiprocess, typer, huggingface-hub, tokenizers, datasets, accelerate, transformers, peft
#   Attempting uninstall: dillm╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/16 [hf-xet]
#     Found existing installation: dill 0.4.0━━━━━━━━━━━━━━━━━━━  5/16 [hf-xet]
#     Uninstalling dill-0.4.0:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/16 [hf-xet]
#       Successfully uninstalled dill-0.4.0━━━━━━━━━━━━━━━━━━━━━  5/16 [hf-xet]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [peft]2m15/16 [peft]formers]ub]
# Successfully installed accelerate-1.13.0 annotated-doc-0.0.4 datasets-4.8.5 dill-0.4.1 hf-xet-1.5.0 huggingface-hub-1.16.1 multiprocess-0.70.19 peft-0.19.1 regex-2026.5.9 safetensors-0.7.0 sentencepiece-0.2.1 shellingham-1.5.4 tokenizers-0.22.2 transformers-5.9.0 typer-0.25.1 xxhash-3.7.0
# missing packages installed: ['transformers', 'datasets', 'peft', 'accelerate', 'sentencepiece']

# %%
from pathlib import Path

import torch
from datasets import load_dataset
from peft import LoraConfig, get_peft_model
from transformers import AutoModelForCausalLM, AutoTokenizer, DataCollatorForLanguageModeling, Trainer, TrainingArguments

BASE_MODEL_ID = "Qwen/Qwen2.5-0.5B-Instruct"
TRAIN_DATASET_FILE = "/data/chapter5/loyalty_qa_train.jsonl"
EVAL_DATASET_FILE = "/data/chapter5/loyalty_qa_val.jsonl"
MODEL_OUTPUT_DIR = Path("/model-assets")
MAX_STEPS = 20
MAX_LENGTH = 512

print("cuda available:", torch.cuda.is_available())
print("train dataset:", TRAIN_DATASET_FILE)
print("eval dataset:", EVAL_DATASET_FILE)
# Out:
# cuda available: True
# train dataset: /data/chapter5/loyalty_qa_train.jsonl
# eval dataset: /data/chapter5/loyalty_qa_val.jsonl

# %%
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL_ID, trust_remote_code=True)
if tokenizer.pad_token is None:
  tokenizer.pad_token = tokenizer.eos_token

model_options = {"torch_dtype": torch.float16 if torch.cuda.is_available() else torch.float32, "trust_remote_code": True}
if torch.cuda.is_available():
  model_options["device_map"] = "auto"

model = AutoModelForCausalLM.from_pretrained(BASE_MODEL_ID, **model_options)
model.config.use_cache = False
model.gradient_checkpointing_enable()
if hasattr(model, "enable_input_require_grads"):
  model.enable_input_require_grads()

config = LoraConfig(
  r=16,
  lora_alpha=32,
  target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
  bias="none",
  lora_dropout=0.05,
  task_type="CAUSAL_LM",
)
model = get_peft_model(model, config)
model.print_trainable_parameters()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# trainable params: 8,798,208 || all params: 502,830,976 || trainable%: 1.7497

# %%
def format_training_text(example):
  messages = [
    {"role": "user", "content": example["prompt"]},
    {"role": "assistant", "content": example["response"]},
  ]
  return tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=False)


def tokenize_dataset(dataset):
  def tokenize_example(example):
    tokens = tokenizer(format_training_text(example), truncation=True, max_length=MAX_LENGTH)
    return tokens

  return dataset.map(tokenize_example, remove_columns=dataset.column_names)


train_dataset = tokenize_dataset(load_dataset("json", data_files=TRAIN_DATASET_FILE, split="train"))
eval_dataset = tokenize_dataset(load_dataset("json", data_files=EVAL_DATASET_FILE, split="train"))
len(train_dataset), len(eval_dataset)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 17
#      12     return tokens
#      14   return dataset.map(tokenize_example, remove_columns=dataset.column_names)
# ---> 17 train_dataset = tokenize_dataset(load_dataset("json", data_files=TRAIN_DATASET_FILE, split="train"))
#      18 eval_dataset = tokenize_dataset(load_dataset("json", data_files=EVAL_DATASET_FILE, split="train"))
#      19 len(train_dataset), len(eval_dataset)
#
# File /opt/conda/lib/python3.13/site-packages/datasets/load.py:1688, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1683 verification_mode = VerificationMode(
#    1684     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1685 )
#    1687 # Create a dataset builder
# -> 1688 builder_instance = load_dataset_builder(
#    1689     path=path,
#    1690     name=name,
#    1691     data_dir=data_dir,
#    1692     data_files=data_files,
#    1693     cache_dir=cache_dir,
#    1694     features=features,
#    1695     download_config=download_config,
#    1696     download_mode=download_mode,
#    1697     revision=revision,
#    1698     token=token,
#    1699     storage_options=storage_options,
#    1700     **config_kwargs,
#    1701 )
#    1703 # Return iterable dataset in case of streaming
#    1704 if streaming:
#
# File /opt/conda/lib/python3.13/site-packages/datasets/load.py:1315, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1313 if features is not None:
#    1314     features = _fix_for_backward_compatible_features(features)
# -> 1315 dataset_module = dataset_module_factory(
#    1316     path,
#    1317     revision=revision,
#    1318     download_config=download_config,
#    1319     download_mode=download_mode,
#    1320     data_dir=data_dir,
#    1321     data_files=data_files,
#    1322     cache_dir=cache_dir,
#    1323 )
#    1324 # Get dataset builder class
#    1325 builder_kwargs = dataset_module.builder_kwargs
#
# File /opt/conda/lib/python3.13/site-packages/datasets/load.py:1055, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1047 # Try packaged
#    1048 if path in _PACKAGED_DATASETS_MODULES:
#    1049     return PackagedDatasetModuleFactory(
#    1050         path,
#    1051         data_dir=data_dir,
#    1052         data_files=data_files,
#    1053         download_config=download_config,
#    1054         download_mode=download_mode,
# -> 1055     ).get_module()
#    1056 # Try locally
#    1057 elif path.endswith(filename):
#
# File /opt/conda/lib/python3.13/site-packages/datasets/load.py:533, in PackagedDatasetModuleFactory.get_module(self)
#     527 base_path = Path(self.data_dir or "").expanduser().resolve().as_posix()
#     528 patterns = (
#     529     sanitize_patterns(self.data_files)
#     530     if self.data_files is not None
#     531     else get_data_patterns(base_path, download_config=self.download_config)
#     532 )
# --> 533 data_files = DataFilesDict.from_patterns(
#     534     patterns,
#     535     download_config=self.download_config,
#     536     base_path=base_path,
#     537 )
#     539 module_path, hash = _PACKAGED_DATASETS_MODULES[self.name]
#     541 builder_kwargs = {
#     542     "data_files": data_files,
#     543     "dataset_name": self.name,
#     544 }
#
# File /opt/conda/lib/python3.13/site-packages/datasets/data_files.py:723, in DataFilesDict.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     718 out = cls()
#     719 for key, patterns_for_key in patterns.items():
#     720     out[key] = (
#     721         patterns_for_key
#     722         if isinstance(patterns_for_key, DataFilesList)
# --> 723         else DataFilesList.from_patterns(
#     724             patterns_for_key,
#     725             base_path=base_path,
#     726             allowed_extensions=allowed_extensions,
#     727             download_config=download_config,
#     728         )
#     729     )
#     730 return out
#
# File /opt/conda/lib/python3.13/site-packages/datasets/data_files.py:616, in DataFilesList.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     613 for pattern in patterns:
#     614     try:
#     615         data_files.extend(
# --> 616             resolve_pattern(
#     617                 pattern,
#     618                 base_path=base_path,
#     619                 allowed_extensions=allowed_extensions,
#     620                 download_config=download_config,
#     621             )
#     622         )
#     623     except FileNotFoundError:
#     624         if not has_magic(pattern):
#
# File /opt/conda/lib/python3.13/site-packages/datasets/data_files.py:403, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     401     if allowed_extensions is not None:
#     402         error_msg += f" with any supported extension {list(allowed_extensions)}"
# --> 403     raise FileNotFoundError(error_msg)
#     404 return out
#
# FileNotFoundError: Unable to find '/data/chapter5/loyalty_qa_train.jsonl'

# %%
def move_inputs_to_device(inputs, device):
  if isinstance(inputs, torch.Tensor):
    return inputs.to(device)
  return {key: value.to(device) for key, value in inputs.items()}


def generate_with_inputs(inputs, **kwargs):
  if isinstance(inputs, torch.Tensor):
    return model.generate(inputs, **kwargs)
  return model.generate(**inputs, **kwargs)


def get_input_length(inputs):
  if isinstance(inputs, torch.Tensor):
    return inputs.shape[-1]
  return inputs["input_ids"].shape[-1]


def generate_text(prompt):
  messages = [{"role": "user", "content": prompt}]
  inputs = move_inputs_to_device(
    tokenizer.apply_chat_template(messages, tokenize=True, add_generation_prompt=True, return_tensors="pt"),
    model.device,
  )
  with torch.no_grad():
    outputs = generate_with_inputs(inputs, max_new_tokens=100, repetition_penalty=1.15)
  return tokenizer.decode(outputs[0][get_input_length(inputs):], skip_special_tokens=True)


eval_prompt = "[MyElite Loyalty Program FAQ]: What is the maximum cashback I can earn?"
print(generate_text(eval_prompt))

# %%
trainer = Trainer(
  model=model,
  train_dataset=train_dataset,
  eval_dataset=eval_dataset,
  args=TrainingArguments(
    output_dir="/tmp/qwen25-myelite-notebook",
    warmup_steps=2,
    per_device_train_batch_size=2,
    gradient_accumulation_steps=1,
    gradient_checkpointing=True,
    max_steps=MAX_STEPS,
    learning_rate=2.5e-5,
    fp16=torch.cuda.is_available(),
    logging_steps=5,
    save_strategy="no",
    eval_strategy="steps",
    eval_steps=10,
    do_eval=True,
    report_to="none",
  ),
  data_collator=DataCollatorForLanguageModeling(tokenizer, mlm=False),
)

trainer.train()

# %%
print(generate_text(eval_prompt))

MODEL_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
trainer.save_model(str(MODEL_OUTPUT_DIR))
tokenizer.save_pretrained(str(MODEL_OUTPUT_DIR))
print("saved:", MODEL_OUTPUT_DIR)
